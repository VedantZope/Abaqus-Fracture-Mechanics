# %%
import numpy as np
import pandas as pd

# %%
output_data=np.loadtxt(f"FD_Curve.txt", skiprows=2)


#print(output_data)
#column 1 is time
#column 2 is disp
#column 3 is force

# Remove X column from output_data
output_data = np.delete(output_data, 0, 1)
forceinkN = output_data[:, 1] * 1e-3 

# Insert into output_data as 2nd column and push Force/N to 3rd column
output_data = np.insert(output_data, 1, forceinkN, axis=1)

print(output_data)
columns=['Disp/mm', 'Force/kN', 'Force/N']
df = pd.DataFrame(data=output_data, columns=columns)
# Save dataframe
df.to_csv('FD_Curve.csv', index=False)


displacement = df.iloc[:, 0].tolist()
print(displacement)
force = df.iloc[:, 1].tolist()
print(force)
# Out:
# [[0.00000e+00 3.12565e-03 3.12565e+00]
#  [3.00013e-02 1.07772e+00 1.07772e+03]
#  [6.00055e-02 2.17217e+00 2.17217e+03]
#  [8.99964e-02 3.31913e+00 3.31913e+03]
#  [1.20005e-01 4.25807e+00 4.25807e+03]
#  [1.50013e-01 5.45100e+00 5.45100e+03]
#  [1.79965e-01 6.02650e+00 6.02650e+03]
#  [2.09917e-01 6.34481e+00 6.34481e+03]
#  [2.39870e-01 6.59948e+00 6.59948e+03]
#  [2.69856e-01 6.83585e+00 6.83585e+03]
#  [2.99860e-01 7.02623e+00 7.02623e+03]
#  [3.29793e-01 7.22769e+00 7.22769e+03]
#  [3.59689e-01 7.42803e+00 7.42803e+03]
#  [3.89590e-01 7.60762e+00 7.60762e+03]
#  [4.19491e-01 7.76148e+00 7.76148e+03]
#  [4.49393e-01 7.86365e+00 7.86365e+03]
#  [4.79294e-01 7.96209e+00 7.96209e+03]
#  [5.09195e-01 8.04128e+00 8.04128e+03]
#  [5.39096e-01 8.12303e+00 8.12303e+03]
#  [5.68997e-01 8.18368e+00 8.18368e+03]
#  [5.99011e-01 8.24762e+00 8.24762e+03]
#  [6.29151e-01 8.30244e+00 8.30244e+03]
#  [6.59296e-01 8.34986e+00 8.34986e+03]
#  [6.89436e-01 8.39545e+00 8.39545e+03]
#  [7.19576e-01 8.43642e+00 8.43642e+03]
#  [7.49721e-01 8.47404e+00 8.47404e+03]
#  [7.79862e-01 8.50929e+00 8.50929e+03]
#  [8.10006e-01 8.54191e+00 8.54191e+03]
#  [8.40147e-01 8.57033e+00 8.57033e+03]
#  [8.70287e-01 8.59550e+00 8.59550e+03]
#  [9.00432e-01 8.62061e+00 8.62061e+03]
#  [9.30572e-01 8.64530e+00 8.64530e+03]
#  [9.60712e-01 8.66538e+00 8.66538e+03]
#  [9.90857e-01 8.68438e+00 8.68438e+03]
#  [1.02100e+00 8.70336e+00 8.70336e+03]
#  [1.05114e+00 8.71860e+00 8.71860e+03]
#  [1.08128e+00 8.73420e+00 8.73420e+03]
#  [1.11142e+00 8.74742e+00 8.74742e+03]
#  [1.14157e+00 8.75993e+00 8.75993e+03]
#  [1.17171e+00 8.77083e+00 8.77083e+03]
#  [1.20185e+00 8.78093e+00 8.78093e+03]
#  [1.23199e+00 8.78928e+00 8.78928e+03]
#  [1.26213e+00 8.79719e+00 8.79719e+03]
#  [1.29227e+00 8.80353e+00 8.80353e+03]
#  [1.32233e+00 8.80875e+00 8.80875e+03]
#  [1.35206e+00 8.81315e+00 8.81315e+03]
#  [1.38179e+00 8.81639e+00 8.81639e+03]
#  [1.41152e+00 8.81862e+00 8.81862e+03]
#  [1.44124e+00 8.81986e+00 8.81986e+03]
#  [1.47097e+00 8.81999e+00 8.81999e+03]
61962, 1.64935, 1.67908, 1.70908, 1.73937, 1.76967, 1.79996, 1.83026, 1.86055, 1.89084, 1.92114, 1.95143, 1.98172, 2.01198, 2.04184, 2.07171, 2.10158, 2.13144, 2.16131, 2.19117, 2.22104, 2.25091, 2.28077, 2.31064, 2.34051, 2.37037, 2.40024, 2.42956, 2.46014, 2.49031, 2.52015, 2.54942, 2.58013, 2.61019, 2.63972, 2.66988, 2.70031, 2.73017, 2.75919, 2.79018, 2.82043, 2.84976, 2.87956, 2.91028, 2.9403, 2.96974, 2.99976]
# [0.0031256499999999998, 1.07772, 2.17217, 3.3191300000000004, 4.25807, 5.4510000000000005, 6.0265, 6.344810000000001, 6.59948, 6.835850000000001, 7.02623, 7.22769, 7.42803, 7.60762, 7.76148, 7.86365, 7.96209, 8.04128, 8.12303, 8.18368, 8.247620000000001, 8.30244, 8.349860000000001, 8.39545, 8.43642, 8.47404, 8.509290000000002, 8.54191, 8.57033, 8.5955, 8.620610000000001, 8.645299999999999, 8.665379999999999, 8.684379999999999, 8.70336, 8.7186, 8.734200000000001, 8.74742, 8.75993, 8.77083, 8.78093, 8.789280000000002, 8.79719, 8.80353, 8.80875, 8.81315, 8.81639, 8.818620000000001, 8.81986, 8.81999, 8.819040000000001, 8.81721, 8.81437, 8.81057, 8.80584, 8.80016, 8.7935, 8.78573, 8.77682, 8.76681, 8.75544, 8.74244, 8.728520000000001, 8.71357, 8.697450000000002, 8.68024, 8.66168, 8.64181, 8.62053, 8.5974, 8.57259, 8.546059999999999, 8.51793, 8.48813, 8.45647, 8.42301, 8.38759, 8.35002, 8.31037, 8.268600000000001, 8.22493, 8.17952, 8.12997, 8.07795, 8.02422, 7.96878, 7.9075299999999995, 7.84467, 7.78042, 7.71099, 7.63809, 7.56396, 7.48844, 7.40565, 7.32214, 7.23828, 7.15167, 7.05909, 6.96691, 6.87527, 6.77867]

# %%
def replace_maxDisp_geometry_inp(filePath, maxDisp):
    with open(filePath, 'r') as geometry_inp:
        geometry_inp_content = geometry_inp.readlines()
    start_line = None
    end_line = None
    for i, line in enumerate(geometry_inp_content[-60:]):
        if line.startswith('*Boundary, amplitude'):
            original_index = len(geometry_inp_content) - 60 + i
            start_line = original_index + 1
            end_line = original_index + 2
            break

    if start_line is None or end_line is None:
        raise ValueError('Could not find the *Boundary, amplitude displacement section')

    new_disp_data = f"Disp, 2, 2, {maxDisp}\n"

    new_lines = []
    new_lines.extend(geometry_inp_content[:start_line])
    new_lines.extend([new_disp_data])
    new_lines.extend(geometry_inp_content[end_line:])

    with open('geometry2.inp', 'w') as file:
        file.writelines(new_lines)

replace_maxDisp_geometry_inp('geometry.inp', 5.0)
# Out:
# 59252
# 59253
# 59254

# %%
def replace_materialName_geometry_inp(filePath):
    with open(filePath, 'r') as geometry_inp:
        geometry_inp_content = geometry_inp.readlines()
    start_line = None
    end_line = None
    for i, line in enumerate(geometry_inp_content[-60:]):
        if line.startswith('*INCLUDE, INPUT='):
            original_index = len(geometry_inp_content) - 60 + i
            start_line = original_index
            end_line = original_index + 1
            break

    if start_line is None or end_line is None:
        raise ValueError('Could not find the **INCLUDE, INPUT= section')

    new_material_data = f"*INCLUDE, INPUT=material.inp\n"

    new_lines = []
    new_lines.extend(geometry_inp_content[:start_line])
    new_lines.extend([new_material_data])
    new_lines.extend(geometry_inp_content[end_line:])

    with open('geometry3.inp', 'w') as file:
        file.writelines(new_lines)

replace_materialName_geometry_inp('geometry.inp')
